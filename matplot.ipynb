# %% [markdown]
# # 1. Prepare Data

# %%
# 1d data
import numpy as np
x = np.linspace(0,10,100)
y = np.cos(x)
z = np.sin(x)

# %%
data = 2 * np.random.random((10,10))
data2 = 3 * np.random.random((10,10))
Y,X = np.mgrid[-3:3:100j,-3:3:100j]
U = -1 - X ** 2 + Y
V = 1 + X -Y ** 2

# %%
from matplotlib.cbook import get_sample_data
img = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))

# %% [markdown]
# # 2. Create plot

# %%
# figure
fig = plt.figure()
fig2 = plt.figure(figsize = plt.figaspect(2.0))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="400">

# %%
# axes
fig.add_axes()
ax1 = fig.add_subplot(221)
ax3 = fig.add_subplot(212) 
fig3,axes = plt.subplots(nrows=2,ncols=2)
fig4,axes2 = plt.subplots(ncols = 3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3.plotting routine

# %%
#1D data
import matplotlib.pyplot as plt
# prepare data
x = np.array([10,20,30,40])
y = np.array([100,200,300,400])

# create plot
fig = plt.figure()
ax = fig.add_subplot(333)
ax1= plt.axes()

'''1D Data'''

'''line graph'''
# lines = ax.plot(x,y)  

'''scatter graph'''
# ax.scatter(x,y)

'''bar graph'''
()
# a1x.bar([1,2,3,],[3,4,5])
# ax1.barh([0.5,1,2.5],[0,1,2])
# ax1.axhline(0.45)
# ax1.axvline(0.65)
# ax1.fill(x,y,color = "red",linewidth=4)
# ax1.fill_between(x,y,color = "yellow")
# plt.show()




'''vector file'''
# ax1.arrow(0,0,0.5,0.5)  '''add an arrow to axes'''

# ax1.quiver(x,y)          '''plot a 2D field of arrow'''

# Y,X = np.mgrid[-3:3:100j,-3:3:100j]
# U = -1 - X ** 2 + Y
# V = 1 + X -Y ** 2
# ax1.streamplot(X,Y,U,V)   '''plot 2d vector fields '''

'''Data Distributions'''

'''Histogram'''
# a  = np.random.normal(size =1000)
# plt.hist(a,bins = 20)            

'''box and whisker plot'''
# ax1.boxplot(y)

'''violin plot'''
# ax1.violinplot(z)


'''2D data '''
# fig, ax= plt.subplots() 
# im = ax.imshow(img,
#               cmap='gist_earth',
#               interpolation ='nearest',
#               vmin=-2,
#               vmax= 2)
'''pseudocolor plot of 2 D array'''
# ax1.pcolor(data2) 
'''pseudocolor plot of 2 D array'''
# ax1.pcolormesh(data)
'''plot filled contours'''
# ax1.contour(data)
'''plot contours'''
cs =plt.contour(Y,X,U)
'''label a contour plot'''
axes2[2]=ax.clabel(cs)
plt.show()

# %% [markdown]
# # 4. Customize plot

# %%
import numpy as np
import matplotlib.pyplot as plt
# prepare data
x = np.array([10,20,30,40])
y = np.array([100,200,300,400])
data = 2 * np.random.random((10,10))
# create plot
fig = plt.figure()
ax = fig.add_subplot(111)
ax1= plt.axes()
'''Colors,color bars and colorsmap'''
# plt.plot(x,x,x,x**2,x,x**3)
# ax.plot(x,y,alpha=0.4)
# ax.plot(x,y,c='k')
# fig.colorbar(im,orientation='horizontal')
# im=ax.imshow(img, cmap='seismic')

'''Markers'''
# fig1,ax2=plt.subplots()
# ax2.scatter(x,y,marker=".")
# ax2.plot(x,y,marker="o")
# plt.show()

'''Linestyle'''
# plt.plot(x,y,linewidth=4.0)
# plt.plot(x,y,ls='solid')
# plt.plot(x,y,ls='--')
# plt.plot(x,y,'--',x**2,y**2,'-.')
# plt.setp(lines,color ='red',linewidth=4.0) doubt(what is this for)

'''Text Annotations'''
# ax.text(1,
#         -2.1,
#        'Example Graph',
#        style='italic')
# ax.annotate("Sine",
#            xy=(0.2,0.2),
#            xycoords='data',
#            xytext=(0.8,0.8),
#            textcoords='data',
#            arrowprops = dict(arrowstyle="->",
#                             connectionstyle="arc3"),
#            )

'''mathtext'''
# plt.title(r'$sigma_i=15$',fontsize = 20)


'''limits legends and layout'''

'''limits and autoscaling'''
# ax.margins(x=0.0, y = 0.1)
# ax.axis('equal')
# ax.set(xlim=[0,10.5],ylim=[-1.5,1.5])
# ax.set_xlim(0,10.5)
'''Legends'''
# ax.set(title ="an example of axes",
#        ylabel='Y-axis',
#        xlabel='X-axis'
#       )
# ax.legend(loc='best')

'''ticks'''
# ax.xaxis.set(ticks=range(1,5),
#             ticklabels=[3,100,-12,"foo"])
# ax.tick_params(axis='y',
#               direction='inout',
#               length=10)

'''Subplot spacing'''
# fig.subplots_adjust(wspace=0.5,
#                     hspace=0.3,
#                     left =0.125,
#                     right=0.9,
#                     top=0.9,
#                     bottom=0.1)
# fig.tight_layout()

'''axis spines'''
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_position(('outward',10))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\jan_env\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %% [markdown]
# # 5.save plot

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure() 
# ax = fig.add_subplot(221)

'''save plot'''
# plt.savefig('foo.png')    '''save fig'''
# plt.savefig('foo.png',transparent=True)    '''save transparent fig'''
 
'''6.show plot'''
# plt.show()
'''close and clear'''
# plt.cla() '''clear axis'''
# plt.clf() '''clear fig'''
# plt.close() '''close a window'''
# Out:
# 'close and clear'

# %% [markdown]
# # creating a graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5,6,7])
y = np.array([5,10,15,20,25,30,35])
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1,2.5,5.2],[10,22,31],color ="lightblue",linewidth=4)
ax.scatter([1.5,2,4.6],[11,26,32], color='red',marker="^")
ax.set_xlim(0,6.5)
plt.savefig('example.png')
plt.show()
